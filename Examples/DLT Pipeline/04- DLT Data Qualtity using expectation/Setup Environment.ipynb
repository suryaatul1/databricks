# %%
# %sql
use catalog dbacademy;

# %%
df=spark.sql("SHOW SCHEMAS LIKE 'lab*'").collect()[0].databaseName
print(df)

spark.sql(f"use schema {df}")

# %%
# %sql
create table twmp_record_to_test_exceptatins as select * from samples.tpch.orders limit 10;

# %%
# %sql
select * from twmp_record_to_test_exceptatins

# %%
# %sql
update twmp_record_to_test_exceptatins
set o_totalprice = -100
where o_orderkey=13710945

# %%
# %sql
select current_date()

# %%
# %sql
update twmp_record_to_test_exceptatins
set o_orderdate = current_date()
where o_orderkey=13710947

# %%
# %sql
update twmp_record_to_test_exceptatins
set o_orderkey=11111

# %%
# %sql
create table temp_customer_table as select * from raw_customer limit 10

# %%
# %sql
select * from temp_customer_table

# %%
# %sql
update temp_customer_table
set c_mktsegment=""
where c_custkey=412445

# %%
# %sql
update temp_customer_table
set c_custkey=9999

# %%
# %sql
insert into raw_customer select * from temp_customer_table

# %%
# %sql
insert into raw_order select * from twmp_record_to_test_exceptatins

# %%
# %sql

create table raw_order deep clone samples.tpch.orders;
create table raw_customer deep clone samples.tpch.customer;

# %%
# %sql
create volume landing;

# %%
dbutils.fs.mkdirs("/Volumes/dbacademy/labuser14322013_1774679369/landing/files")
dbutils.fs.mkdirs("/Volumes/dbacademy/labuser14322013_1774679369/landing/autoloader/schemas")

# %%
# %sql

insert into dbacademy.labuser14322013_1774611990.raw_order select * from samples.tpch.orders limit 10000;

# %%
# %sql

insert into dbacademy.labuser14322013_1774679369.raw_order select * from samples.tpch.orders limit 5000;

# %%
# %sql
select * from raw_customer
