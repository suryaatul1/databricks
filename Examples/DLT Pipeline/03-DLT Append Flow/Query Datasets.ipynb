# %%
spark.sql("use catalog dbacademy")

df=spark.sql("SHOW SCHEMAS LIKE 'lab*'").collect()[0].databaseName
print(df)

spark.sql(f"use schema {df}")

# %%
# %sql

select * from raw_order limit 10000

# %%
# %sql

select * from raw_order limit 5
