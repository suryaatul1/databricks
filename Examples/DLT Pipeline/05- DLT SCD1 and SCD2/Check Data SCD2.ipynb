# %%
# %sql
use catalog dbacademy;
use schema labuser14322013_1774698898

# %%
# %sql
select * from dbacademy.labuser14322013_1774698898.customer_scd2_bronze where c_custkey in (412451,
412452,
412453,
412454)

# %%
# %sql
update customer_raw_scd2 
set __src_action ='U' , _src_insert_dt = current_timestamp() , c_mktsegment="XXXX"  , c_phone="ZZZZ"

# %%
# %sql
insert into raw_customer select * from customer_raw_scd2

# %% [markdown]
# # Before SCD2

# %%
# %sql
select * from dbacademy.labuser14322013_1774698898.customer_scd2_bronze where c_custkey in (412451,
412452,
412453,
412454)

# %% [markdown]
# #AFTER SCD2

# %%
# %sql
select * from dbacademy.labuser14322013_1774698898.customer_scd2_bronze where c_custkey in (412451,
412452,
412453,
412454)
