# %%
# %sql
use catalog dbacademy;
use schema labuser14322013_1774698898

# %%
# %sql
select * from dbacademy.labuser14322013_1774698898.customer_scd1_bronze

# %%
# %sql
select * from raw_customer

# %%
# %sql
select * from dbacademy.labuser14322013_1774698898.orders_gold

# %% [markdown]
# #Perform SCD1

# %%
# %sql
select * from dbacademy.labuser14322013_1774698898.customer_raw_scd1

# %%
# %sql
insert into dbacademy.labuser14322013_1774698898.raw_customer 
select * from dbacademy.labuser14322013_1774698898.customer_raw_scd1

# %% [markdown]
# #Before SCD1 records update and process

# %%
# %sql

select * from dbacademy.labuser14322013_1774698898.customer_raw_scd1
where c_custkey in (412445,
412446,
412447,
412448,
412449,
412450)

# %% [markdown]
# #After SCD Records arrived and process executed

# %%
# %sql
select * from dbacademy.labuser14322013_1774698898.customer_scd1_bronze
where c_custkey in (412445,
412446,
412447,
412448,
412449,
412450)

# %% [markdown]
# # Another SCD with null market segments

# %%
# %sql
update customer_raw_scd1 
set __src_action ='II' , _src_insert_dt = current_timestamp() , c_mktsegment=""  , c_phone=""

# %%
# %sql
insert into dbacademy.labuser14322013_1774698898.raw_customer 
select * from dbacademy.labuser14322013_1774698898.customer_raw_scd1

# %% [markdown]
# # Before

# %%
# %sql
select * from dbacademy.labuser14322013_1774698898.customer_scd1_bronze where c_custkey in (412445,
412446,
412447,
412448,
412449,
412450)

# %% [markdown]
# #AFTER

# %%
# Phone number and market segments gone

# %sql
select * from dbacademy.labuser14322013_1774698898.customer_scd1_bronze where c_custkey in (412445,
412446,
412447,
412448,
412449,
412450)
